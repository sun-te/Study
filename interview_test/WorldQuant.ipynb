# %% [markdown]
# ### 什么是内存溢出
# 内存泄漏（Memory Leak）是指程序中己动态分配的堆内存由于某种原因程序未释放或无法释放，造成系统内存的浪费，导致程序运行速度减慢甚至系统崩溃等严重后果。系统中存在无法回收的内存或使用的内存过多，最终使得程序运行要用到的内存大于能提供的最大内存。
#
# 原因：
#
# 第一种是由于长期保持某些资源的引用，垃圾回收器无法回收它，从而使该资源不能够及时释放，也称为内存泄露； [2]
# 另外一种是当需要保存多个耗用内存过大或当加载单个超大的对象时，该对象的大小超过了当前剩余的可用内存空间。
#
# 解决方案：
#
# - 检查代码是否有死循环和过分的递归
# - 数据库是否由大量一次性读取
# - 大型变量使用完后是否没有释放
# - 直接检查内存，使用内存内部直接释放
#
# ### Machine Learning
# 对于捉罪犯和检验员工是否迟到（旷工），机器学习会有什么区别， recall rate分别是什么样的情况？
#
# True Positive(真正，TP)：将正类预测为正类数
#
# True Negative(真负，TN)：将负类预测为负类数
#
# False Positive(假正，FP)：将负类预测为正类数误报 (Type I error)
#
# False Negative(假负，FN)：将正类预测为负类数→漏报 (Type II error)
#
# $$Precision = \frac{TP}{FP + TP} = \frac{预测对的正类}{所有预测为正类的样本数}$$
# $$Recall = \frac{TP}{FN + TP}= \frac{预测对的正类}{所有真正的正类}$$
# $$Accuracy = \frac{TP  + TN}{ALL}$$
#
# 抓罪犯的recall率会高一些，因为会抓很多人也不要放过罪犯，因此所有的P被抓到的概率会大一些
#
# ### 贝叶斯天气预测
# A和B两个公司，他们预测天气的准确率都是60%，那么他们都预测了明天天气为晴天，明天真正晴天的概率是多少？
#
# 设：X事件：A站预报明天下雨Y事件：B站预报明天下雨R事件：明天下雨已知X，Y独立。题目求P（R|X，Y）。由Bayes公式：
# $$P（R|X）= P（X，R）/ P（X）= P（X|R）P（R）/ P（X）$$
#
# 同理：
# $$P（R|Y）= P（Y，R）/ P（Y）= P（X|R）P（R）/ P（Y）$$
#
# 得出：
#
# $$P（X|R）= P（R|X）P（X）/ P（R）= 0.9 P（X）/ P（R）P（Y|R）= P（R|Y）P（Y）/ P（R）= 0.8 P（Y）/ P（R）$$
#
# X，Y 是independent，所以：
#
# $$P（X，Y）= P（X）P（Y）P（X，Y|R）= P（X|R）P（Y|R）$$
# 再次用Bayes公式：$$P（X，Y，R）= P（X，Y|R）P（R）= P（X|R）P（Y|R）P（R）= P（R|X，Y）P（X，Y）$$
#
# 所以最终：
#
# $$P（R|X，Y）= P（X|R）P（Y|R）P（R）/ P（X，Y）= 0.72/P（R）$$

# %% [markdown]
# ### 数学题：
#
# 两个uniform distribution, var X, Y，$$U[0,1]$$ 求$$E(max(X,Y))$$

# %% [markdown]
# ### 算法题：（Edit distance）
#
# https://leetcode.com/problems/edit-distance/
#
# 最少用多少操作可以让字符X（ex:"ABCELDJREFDCR"）变为Y（ex:"AEKCOEFJR"）,（X的长度n）>（Y的长度m）
#
# Given two words word1 and word2, find the minimum number of operations required to convert word1 to word2.
#
# You have the following 3 operations permitted on a word:
#
#     Insert a character
#     Delete a character
#     Replace a character
#
# **Example1**
# ```
# Input: word1 = "horse", word2 = "ros"
# Output: 3
# Explanation:
# horse -> rorse (replace 'h' with 'r')
# rorse -> rose (remove 'r')
# rose -> ros (remove 'e')
# ```
# **Example2**
# ```
# Input: word1 = "intention", word2 = "execution"
# Output: 5
# Explanation:
# intention -> inention (remove 't')
# inention -> enention (replace 'i' with 'e')
# enention -> exention (replace 'n' with 'x')
# exention -> exection (replace 'n' with 'c')
# exection -> execution (insert 'u')
# ```
# ### Solution: recursive (compare two cases:  edit or move)or DP

# %% [markdown]
# # 第二轮
#
# ## 2.1
# 1. 两个人赌注，每次筹码少的人要全下注，另一个人则下同样的赌注。一轮赌注中获胜者可以把所有场上的筹码收回。例如a有8分，b有3分，大家均下注3分，若b赢了则b会变成6分而a变成5分，若b输了则b破产，游戏结束。一个不会结束的例子：a有4，b有1，一轮后可变成a：3，b：2，再一轮后可以变为a：1，b：4。可以说是回到了初始状态，因此这种配置可以永远循环下去
#
# 答案：`WQ_Question20191216.pdf`
#
# 2. 各种排序算法的优劣评判， 如何证明快排的算法效率
#
# 3. hedge和二级市场的区别:存在卖空
#
# 4. 什么是$\alpha$，怎么理解：能够套利的数学模型
# ## 2.2
# 1.
# $$\lim_{x\rightarrow\infty}\frac{\int_{1}^{x} t^2 (e^{1/t}-1) - t}{x^2 ln(1+1/x)}$$
# 答案： $\frac{1}{2}$
#
# 2. 查找中位数的算法
#
# 3. 矩阵乘法算法的最优算法？
